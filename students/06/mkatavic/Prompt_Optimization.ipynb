# %%
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
import google.generativeai as genai
genai.configure(api_key=GOOGLE_API_KEY)

import json
import re
import time
from typing import Dict, Any

from tenacity import (
    retry,
    wait_exponential,
    stop_after_attempt,
    retry_if_exception_type,
)
import google.generativeai.types as genai_types
from google.api_core.exceptions import TooManyRequests


# --- MODEL SETUP (Assuming global availability in this execution environment) ---
# Judge/Thinking Model (Gemini 2.5 Pro for best reasoning)
gemini_model_thinking = genai.GenerativeModel('gemini-2.5-pro')

# Student/Lite Model (Gemini 2.0 Flash-Lite for speed/cost)
gemini_model_lite = genai.GenerativeModel('gemini-2.0-flash-lite')
# ------------------------------------------------------------------------------


# ==============================
# Prompt optimization function
# ==============================

def get_feedback_and_optimized_prompt(
    lite_model_prompt: str,
    lite_model_output: str,
    task_input: str,
    task_expected_output: str
) -> Dict[str, str]:
    """
    Evaluates the lite_model_output against the task and the prompt using
    gemini_model_thinking to generate an optimized prompt, feedback, and
    rationale.
    """

    optimization_instruction = f"""
    You are a prompt optimizer (Gemini 2.5 Pro). Your task is to evaluate a
    `lite_model_output` (from Gemini 2.0 Flash-Lite) against a given task.

    Task: Croatian to English Technical Translation.
    Evaluation Criteria:
    1. Accuracy (Correct translation of meaning).
    2. Terminology Preservation (e.g., 'funkcija' MUST be translated as 'function').
    3. Output Format (ONLY the English translation text should be returned, no extra commentary).

    Based on this evaluation, provide constructive feedback and suggest an
    `optimized_prompt` for the Lite model to produce a better output.

    Your output MUST be in JSON format with the following keys:
    - `optimized_prompt`: The new, improved prompt for the lite model.
    - `feedback_text`: Detailed feedback (1-3 sentences) on the Lite model's output and how the new prompt addresses the issues.
    - `rationale`: Explanation of the reasoning behind the optimization, focusing on why the changes improve the chance of success with a smaller model.
    - `grade`: A simple qualitative assessment: 'Perfect', 'Good', 'Needs Improvement'.

    --- Input for Evaluation ---
    Task Input (Croatian): "{task_input}"
    Task Expected Output (English): "{task_expected_output}"
    Original Prompt: "{lite_model_prompt}"
    Lite Model Output: "{lite_model_output}"

    Please provide your optimized prompt, feedback, and rationale in JSON format.
    """

    # Retry helper functions (omitted for brevity, assume they work as in the original)
    def _extract_retry_after_seconds(exc: Exception) -> float | None:
        message = str(exc)
        match = re.search(r"Please retry in ([0-9.]+)s", message)
        if match:
            try:
                return float(match.group(1))
            except ValueError:
                return None
        return None

    @retry(
        wait=wait_exponential(multiplier=1, min=4, max=10),
        stop=stop_after_attempt(5),
        retry=retry_if_exception_type(
            (genai_types.BlockedPromptException, TooManyRequests)
        ),
        reraise=True,
    )
    def call_gemini_model_thinking_with_retry(instruction: str):
        try:
            return gemini_model_thinking.generate_content(instruction)
        except genai_types.BlockedPromptException as e:
            print(f"Caught BlockedPromptException: {e}. Retrying...", flush=True)
            raise
        except TooManyRequests as e:
            retry_after = _extract_retry_after_seconds(e)
            if retry_after is not None:
                capped_delay = min(retry_after, 60.0)
                time.sleep(capped_delay)
            raise

    response = None
    try:
        response = call_gemini_model_thinking_with_retry(optimization_instruction)
        raw_text = getattr(response, "text", str(response))

        # Extract JSON string from potentially markdown-formatted response
        json_match = re.search(r"```json\n([\s\S]*?)\n```", raw_text)
        json_string = json_match.group(1) if json_match else raw_text

        optimization_results = json.loads(json_string)

        return {
            "optimized_prompt": optimization_results.get("optimized_prompt", lite_model_prompt),
            "feedback_text": optimization_results.get("feedback_text", "Could not parse feedback."),
            "rationale": optimization_results.get("rationale", "Could not parse rationale."),
            "grade": optimization_results.get("grade", "Error"),
        }

    except Exception as e:
        print(f"An error occurred during optimization: {e}", flush=True)
        return {
            "optimized_prompt": lite_model_prompt,
            "feedback_text": f"Optimization failed: {e}",
            "rationale": "Optimization step skipped due to error.",
            "grade": "Error",
        }


# ==============================
# Streaming optimization loop
# (Adapted to include task-specific input)
# ==============================

def run_optimization_loop(
    initial_prompt: str,
    task_input: str,
    task_expected_output: str,
    num_turns: int = 5,
):
    """
    Runs the lite model + thinking model optimization loop for the translation task.
    """
    current_prompt = initial_prompt
    history = []

    for turn in range(1, num_turns + 1):
        print(f"--- Optimization Turn {turn} ---", flush=True)

        # Full prompt includes the current optimized prompt + the task input
        full_lite_prompt = f"{current_prompt}\n\nCroatian Text: \"{task_input}\""

        # 1) PROMPT SENT TO LITE MODEL
        print("Lite Model's Full Input Prompt:", flush=True)
        print("------------------------------------------------", flush=True)
        print(full_lite_prompt, flush=True)
        print("------------------------------------------------", flush=True)

        # 2) LITE MODEL OUTPUT
        lite_response = gemini_model_lite.generate_content(full_lite_prompt)
        lite_output_text = getattr(lite_response, "text", "").strip()

        print("\nLite Model Output:", flush=True)
        print(lite_output_text, flush=True)
        print()  # blank line

        # 3) FEEDBACK + RATIONALE + NEW OPTIMIZED PROMPT (using the thinking model)
        feedback_results = get_feedback_and_optimized_prompt(
            lite_model_prompt=current_prompt, # Only pass the system part of the prompt
            lite_model_output=lite_output_text,
            task_input=task_input,
            task_expected_output=task_expected_output
        )

        feedback_text = feedback_results.get("feedback_text", "")
        rationale = feedback_results.get("rationale", "")
        optimized_prompt = feedback_results.get("optimized_prompt", current_prompt)
        grade = feedback_results.get("grade", "N/A")

        print("--- Feedback from Gemini 2.5 Pro ---", flush=True)
        print(f"Grade: {grade}", flush=True)
        print("Feedback:", flush=True)
        print(feedback_text, flush=True)
        print("Rationale:", flush=True)
        print(rationale, flush=True)
        print(
            "New Optimized Prompt (for next turn):",
            optimized_prompt,
            flush=True,
        )
        print("------------------------------------------------", flush=True)

        # Save history
        history.append({
            "turn": turn,
            "prompt": current_prompt,
            "output": lite_output_text,
            "grade": grade,
            "feedback": feedback_text
        })

        # Update prompt for next turn
        current_prompt = optimized_prompt

    print("\n--- OPTIMIZATION SUMMARY ---", flush=True)
    for h in history:
        print(f"Turn {h['turn']} | Grade: {h['grade']} | Prompt: {h['prompt'][:70]}...", flush=True)

# -------------------------------------------------------------
# EXECUTION SETUP
# -------------------------------------------------------------

# 1. Define task parameters
TASK_INPUT_CROATIAN = "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
TASK_EXPECTED_ENGLISH = "The dashboard shows the current system load and errors in the data processing function."

# 2. Write initial system prompt for Flash-Lite
INITIAL_PROMPT = (
    "Translate the following Croatian technical sentence into English. "
    "Do not include any commentary, explanations, or prefixes. Just output the translation."
)

# 3. Set iteration count
NUM_ITERATIONS = 5

# 4. Run the optimization loop
run_optimization_loop(
    initial_prompt=INITIAL_PROMPT,
    task_input=TASK_INPUT_CROATIAN,
    task_expected_output=TASK_EXPECTED_ENGLISH,
    num_turns=NUM_ITERATIONS
)
# Out:
# --- Optimization Turn 1 ---
# Lite Model's Full Input Prompt:
# ------------------------------------------------
# Translate the following Croatian technical sentence into English. Do not include any commentary, explanations, or prefixes. Just output the translation.
#
# Croatian Text: "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
# ------------------------------------------------
#
# Lite Model Output:
# The dashboard displays the current system load and errors in the data processing functions.
#
# --- Feedback from Gemini 2.5 Pro ---
# Grade: Good
# Feedback:
# The lite model's translation was accurate in meaning but incorrectly pluralized the key term 'function' to 'functions'. The optimized prompt adds an explicit rule and a one-shot example to guide the model in correctly preserving the grammatical number of specific technical terms. This direct guidance significantly increases the chance of a precise translation.
# Rationale:
# Lite models benefit from highly explicit instructions and examples (in-context learning). The original prompt was too generic. The optimized prompt specifies a role (expert translator), provides a direct, non-negotiable rule for the exact term that failed ('funkcija' -> 'function'), and includes a simple one-shot example demonstrating the rule in action. This structured approach reduces ambiguity and helps the smaller model follow the specific constraints without making incorrect inferences.
# New Optimized Prompt (for next turn): You are an expert Croatian-to-English technical translator specializing in software documentation.
#
# Your task is to translate the Croatian text into English adhering to these rules:
# 1.  **Terminology Rule:** The Croatian word 'funkcija' MUST be translated as the English word 'function'. Preserve the grammatical number (singular/plural) from the source.
# 2.  **Format Rule:** Your output must ONLY be the translated English text. Do not include any prefixes, explanations, or commentary.
#
# --- Example ---
# Croatian: "Sustav ima novu funkciju."
# English: "The system has a new function."
#
# --- Translate This ---
# "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
# ------------------------------------------------
# --- Optimization Turn 2 ---
# Lite Model's Full Input Prompt:
# ------------------------------------------------
# You are an expert Croatian-to-English technical translator specializing in software documentation.
#
# Your task is to translate the Croatian text into English adhering to these rules:
# 1.  **Terminology Rule:** The Croatian word 'funkcija' MUST be translated as the English word 'function'. Preserve the grammatical number (singular/plural) from the source.
# 2.  **Format Rule:** Your output must ONLY be the translated English text. Do not include any prefixes, explanations, or commentary.
#
# --- Example ---
# Croatian: "Sustav ima novu funkciju."
# English: "The system has a new function."
#
# --- Translate This ---
# "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
#
# Croatian Text: "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
# ------------------------------------------------
#
# Lite Model Output:
# The dashboard displays the current system load and errors in the data processing function.
#
# --- Feedback from Gemini 2.5 Pro ---
# Grade: Perfect
# Feedback:
# The Lite model's output was perfect, correctly translating the meaning, adhering to the terminology rule for 'funkcija', and following the specified output format. The optimized prompt reinforces these strict rules with more direct, imperative language to ensure consistent success with a smaller model.
# Rationale:
# The original prompt was excellent. The optimization focuses on making the instructions even more direct and unambiguous for a smaller model by using imperative commands ('Translate the text below:'), consolidating constraints under a 'CRITICAL RULES' heading, and simplifying the persona declaration. This reduces the chance of misinterpretation and reinforces the most important constraints.
# New Optimized Prompt (for next turn): As a technical translator, translate the following Croatian text to English.
#
# **CRITICAL RULES:**
# - **Terminology:** The Croatian 'funkcija' must be translated as the English 'function'.
# - **Output:** Provide ONLY the English translation. No other text or explanation.
#
# **Example:**
# Croatian: "Sustav ima novu funkciju."
# English: "The system has a new function."
#
# **Translate the text below:**
# "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
# ------------------------------------------------
# --- Optimization Turn 3 ---
# Lite Model's Full Input Prompt:
# ------------------------------------------------
# As a technical translator, translate the following Croatian text to English.
#
# **CRITICAL RULES:**
# - **Terminology:** The Croatian 'funkcija' must be translated as the English 'function'.
# - **Output:** Provide ONLY the English translation. No other text or explanation.
#
# **Example:**
# Croatian: "Sustav ima novu funkciju."
# English: "The system has a new function."
#
# **Translate the text below:**
# "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
#
# Croatian Text: "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
# ------------------------------------------------
#
# Lite Model Output:
# The dashboard displays the current system load and errors in the data processing function.
#
# --- Feedback from Gemini 2.5 Pro ---
# Grade: Perfect
# Feedback:
# The lite model's output was perfect, correctly adhering to all instructions regarding accuracy, terminology, and output format. The optimized prompt refines the original by using a more structured, machine-readable format with clear headings and lists, which enhances reliability and makes the prompt a more robust template for smaller models.
# Rationale:
# The optimization focuses on structure and clarity, as the original prompt's content was already effective. By using markdown headers (# ROLE, # RULES) and explicit INPUT/OUTPUT sections, the prompt becomes less conversational and more like a structured command. This reduces the cognitive load on a smaller model, making it easier to parse the critical constraints and consistently follow the strict formatting rule.
# New Optimized Prompt (for next turn): # ROLE: Croatian-to-English Technical Translator
#
# # TASK: Translate the provided Croatian text into English.
#
# # RULES:
# 1.  **Accuracy:** Provide a direct and accurate technical translation.
# 2.  **Terminology:** The Croatian word 'funkcija' MUST be translated as the English word 'function'.
# 3.  **Format:** Output ONLY the English translation. Do not include any other text, labels, or explanations.
#
# # EXAMPLE:
# -   **Croatian:** "Sustav ima novu funkciju."
# -   **English:** "The system has a new function."
#
# # INPUT:
# -   **Croatian:** "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
#
# # OUTPUT:
# -   **English:**
# ------------------------------------------------
# --- Optimization Turn 4 ---
# Lite Model's Full Input Prompt:
# ------------------------------------------------
# # ROLE: Croatian-to-English Technical Translator
#
# # TASK: Translate the provided Croatian text into English.
#
# # RULES:
# 1.  **Accuracy:** Provide a direct and accurate technical translation.
# 2.  **Terminology:** The Croatian word 'funkcija' MUST be translated as the English word 'function'.
# 3.  **Format:** Output ONLY the English translation. Do not include any other text, labels, or explanations.
#
# # EXAMPLE:
# -   **Croatian:** "Sustav ima novu funkciju."
# -   **English:** "The system has a new function."
#
# # INPUT:
# -   **Croatian:** "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
#
# # OUTPUT:
# -   **English:**
#
# Croatian Text: "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
# ------------------------------------------------
#
# Lite Model Output:
# The dashboard displays the current system load and errors in the data processing function.
#
# --- Feedback from Gemini 2.5 Pro ---
# Grade: Perfect
# Feedback:
# The lite model's output was perfect, correctly translating the meaning, preserving the required terminology, and adhering to the specified format. The optimized prompt strengthens the original structure and adds an explicit instruction to handle minor grammatical errors in the source text (like 'u funkcija' instead of 'u funkciji'), making it more robust for future, potentially imperfect inputs.
# Rationale:
# The original prompt was very effective. The optimization makes it more resilient by using clearer structural headers (`CONSTRAINTS`, `TRANSLATION`) and adding a rule for implicit grammar correction. This reduces the model's need to infer how to handle flawed inputs, which is a key strategy for improving reliability with smaller models.
# New Optimized Prompt (for next turn): # ROLE
# You are an expert Croatian-to-English technical translator.
#
# # TASK
# Translate the provided Croatian technical text into English, adhering strictly to the following constraints.
#
# # CONSTRAINTS
# 1.  **Direct Translation:** Translate the meaning accurately and directly.
# 2.  **Strict Terminology:** The Croatian word 'funkcija' MUST be translated as 'function'.
# 3.  **Grammar Correction:** If the source Croatian has minor grammatical errors (e.g., incorrect case), translate the intended correct meaning.
# 4.  **Clean Output:** Provide ONLY the final English translation. Do not include any headers, labels, or explanatory text.
#
# # EXAMPLE
# -   Croatian Input: "Sustav ima novu funkciju."
# -   English Output: "The system has a new function."
#
# # TRANSLATION
# -   Croatian Input: "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
# -   English Output:
# ------------------------------------------------
# --- Optimization Turn 5 ---
# Lite Model's Full Input Prompt:
# ------------------------------------------------
# # ROLE
# You are an expert Croatian-to-English technical translator.
#
# # TASK
# Translate the provided Croatian technical text into English, adhering strictly to the following constraints.
#
# # CONSTRAINTS
# 1.  **Direct Translation:** Translate the meaning accurately and directly.
# 2.  **Strict Terminology:** The Croatian word 'funkcija' MUST be translated as 'function'.
# 3.  **Grammar Correction:** If the source Croatian has minor grammatical errors (e.g., incorrect case), translate the intended correct meaning.
# 4.  **Clean Output:** Provide ONLY the final English translation. Do not include any headers, labels, or explanatory text.
#
# # EXAMPLE
# -   Croatian Input: "Sustav ima novu funkciju."
# -   English Output: "The system has a new function."
#
# # TRANSLATION
# -   Croatian Input: "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
# -   English Output:
#
# Croatian Text: "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
# ------------------------------------------------
#
# Lite Model Output:
# The dashboard displays the current system load and errors in the data processing function.
#
# --- Feedback from Gemini 2.5 Pro ---
# Grade: Perfect
# Feedback:
# The Lite model's output was perfect, meeting all evaluation criteria for accuracy, terminology, and format. The optimized prompt refines the structure by using a more direct, rule-based format and a clear example-then-task pattern, which enhances consistency and reduces complexity for a lite model.
# Rationale:
# Lite models perform best with explicit, simple, and structured instructions. The optimized prompt removes descriptive headers like '# ROLE' and replaces them with direct commands and a clear 'Rules' section. Using a strong few-shot example followed by the actual task with a final `English:` cue creates an unambiguous pattern for the model to follow, which is a highly effective technique for ensuring precise formatting and adherence to constraints.
# New Optimized Prompt (for next turn): Translate the Croatian technical text to English.
#
# **Rules:**
# - The Croatian word 'funkcija' MUST be translated as 'function'.
# - Correct any minor grammatical errors in the source text for a fluent translation.
# - Provide ONLY the final English translation.
#
# **Example:**
# Croatian: "Sustav ima novu funkciju."
# English: "The system has a new function."
#
# **Translate the following:**
# Croatian: "Nadzorna ploča prikazuje trenutno opterećenje sustava i greške u funkcija obrade podataka."
# English:
# ------------------------------------------------
#
# --- OPTIMIZATION SUMMARY ---
# Turn 1 | Grade: Good | Prompt: Translate the following Croatian technical sentence into English. Do n...
# Turn 2 | Grade: Perfect | Prompt: You are an expert Croatian-to-English technical translator specializin...
# Turn 3 | Grade: Perfect | Prompt: As a technical translator, translate the following Croatian text to En...
# Turn 4 | Grade: Perfect | Prompt: # ROLE: Croatian-to-English Technical Translator
#
# # TASK: Translate th...
# Turn 5 | Grade: Perfect | Prompt: # ROLE
# You are an expert Croatian-to-English technical translator.
#
# # ...
